# %% [markdown]
# ### Loading All Necessary Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Importing the dataset 

fuel_data = pd.read_csv('fuel_data.csv')
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %% [markdown]
# #### Question 3
#
# Which of the following fuel type code has the lowest average fuel cost per unit burned?

# %%
# To check which fuel type code has the lowest average fuel cost per unit burned

fuel_data[fuel_data.fuel_cost_per_unit_burned == fuel_data.fuel_cost_per_unit_burned.min()]

# Ans = Waste
# Out:
#                     record_id  utility_id_ferc1  report_year  \
# 7733  f1_fuel_2000_12_194_3_3               194         2000
#
#          plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 7733  nelson dewey unit 2               waste       ton             39.0
#
#       fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 7733               0.0155                    -276.08
#
#       fuel_cost_per_unit_delivered  fuel_cost_per_mmbtu
# 7733                       -174.67               -8.906

# %% [markdown]
# #### Question 4
# What is the standard deviation and 75th percentile of the measure of energy per unit (Fuel_mmbtu_per_unit) in two decimal places?

# %%
#To get std and 75% of fuel_mmbtu_per_unit

fuel_data.describe()

# std = 10.60
# 75% = 17.01
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %% [markdown]
# #### Question 5
# What is the skewness and kurtosis for the fuel quantity burned in two decimal places?

# %%
# To get skewness for the fuel quantity burned
fuel_data.skew(axis = 0, skipna = True) 

# Ans = 15.85
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
# To get Kurtosis for the fuel quantity burned
fuel_data.kurtosis(axis = 0, skipna = True)

#Ans = 651.36
# Out:
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64

# %% [markdown]
# #### Question 6
# Which feature has missing values and what is the total number of missing value and percentage of the missing rows as a factor of the total number of rows in three decimal places?
#
# (Enter answer in the format: Feature: xxx, Total: xxx, Percent: xxx)

# %%
# To check for missing values
tot_missing_values = fuel_data.isnull().sum()
print(tot_missing_values)

total_number_of_rows = len(fuel_data)
print(total_number_of_rows)

#To get the percentage 
missing_values_as_perecentage = ((tot_missing_values)/(total_number_of_rows))*100
print(missing_values_as_perecentage)

# Feature = Fuel Unit 
# Total = 180 
# Percentage = 0.61%
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64
# 29523
# record_id                       0.000000
# utility_id_ferc1                0.000000
# report_year                     0.000000
# plant_name_ferc1                0.000000
# fuel_type_code_pudl             0.000000
# fuel_unit                       0.609694
# fuel_qty_burned                 0.000000
# fuel_mmbtu_per_unit             0.000000
# fuel_cost_per_unit_burned       0.000000
# fuel_cost_per_unit_delivered    0.000000
# fuel_cost_per_mmbtu             0.000000
# dtype: float64

# %% [markdown]
# #### Question 8
# Which of the features has the second and third lowest correlation with the Fuel Cost Per Unit Burned?

# %%
# To find the correlation among the columns using the standard method
fuel_data.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
# To find the correlation among the columns using kendall method 
fuel_data.corr(method ='kendall')

# Ans = 'utility_id_ferc1' and 'report_year'
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.046176        -0.034217
# report_year                           0.046176     1.000000        -0.053437
# fuel_qty_burned                      -0.034217    -0.053437         1.000000
# fuel_mmbtu_per_unit                  -0.064722    -0.030246         0.054576
# fuel_cost_per_unit_burned            -0.049750     0.164699        -0.261359
# fuel_cost_per_unit_delivered         -0.045562     0.125741        -0.176655
# fuel_cost_per_mmbtu                  -0.011386     0.266284        -0.363151
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.064722                  -0.049750
# report_year                             -0.030246                   0.164699
# fuel_qty_burned                          0.054576                  -0.261359
# ...

# %% [markdown]
# Please note: I used the kendall method when calculating the corrolations in question 8. Which is probably why i got the question wrong on the quiz

# %% [markdown]
# #### Question 10
# Which year has the highest average fuel cost per unit delivered?

# %%
# To check which year has the highest average fuel cost per unit delivered

fuel_data[fuel_data.fuel_cost_per_unit_delivered == fuel_data.fuel_cost_per_unit_delivered.max()]

# Ans = 1997
# Out:
#                   record_id  utility_id_ferc1  report_year plant_name_ferc1  \
# 3564  f1_fuel_1997_12_9_0_8                 9         1997     peach bt 2&3
#
#      fuel_type_code_pudl fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 3564             nuclear    gramsU         210474.0             0.000065
#
#       fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# 3564                     37.847                     7964521.0
#
#       fuel_cost_per_mmbtu
# 3564                0.578
